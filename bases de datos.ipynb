# %% [markdown]
# #Lectura de datos
# ##Base de datis: almacena, agrupa y codifica estructuras de datos
# ###Información:
# - Numérica
# -Objetos
# - Etiquetas
# ###Búsqueda de información (fuentes):
# - Wikipedia
# - Kaggle
# - INEGI
# ###excel, csv, textos (.xlxs, .csv, .txt)

# %%
immport pandas as pd

# %%
data = pd.read_csv()#entre parentesis poner el nombre del archivo
